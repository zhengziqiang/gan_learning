# %%
import os
lines=file("/home/zzq/Downloads/fer2013/fer2013.csv",'r').readlines()

# %%
print len(lines)
# Out:
# 35888

# %%
print lines[0]
# Out:
# emotion,pixels,Usage

# %%
lin1=lines[1]
lin1_=lin1.split(',')
num_f=lin1[1].split(' ')
print len(num_f)
# Out:
# 1

# %%
print lin1
# Out:
# 0,70 80 82 72 58 58 60 63 54 58 60 48 89 115 121 119 115 110 98 91 84 84 90 99 110 126 143 153 158 171 169 172 169 165 129 110 113 107 95 79 66 62 56 57 61 52 43 41 65 61 58 57 56 69 75 70 65 56 54 105 146 154 151 151 155 155 150 147 147 148 152 158 164 172 177 182 186 189 188 190 188 180 167 116 95 103 97 77 72 62 55 58 54 56 52 44 50 43 54 64 63 71 68 64 52 66 119 156 161 164 163 164 167 168 170 174 175 176 178 179 183 187 190 195 197 198 197 198 195 191 190 145 86 100 90 65 57 60 54 51 41 49 56 47 38 44 63 55 46 52 54 55 83 138 157 158 165 168 172 171 173 176 179 179 180 182 185 187 189 189 192 197 200 199 196 198 200 198 197 177 91 87 96 58 58 59 51 42 37 41 47 45 37 35 36 30 41 47 59 94 141 159 161 161 164 170 171 172 176 178 179 182 183 183 187 189 192 192 194 195 200 200 199 199 200 201 197 193 111 71 108 69 55 61 51 42 43 56 54 44 24 29 31 45 61 72 100 136 150 159 163 162 163 170 172 171 174 177 177 180 187 186 187 189 192 192 194 195 196 197 199 200 201 200 197 201 137 58 98
# ...

# %%
print lin1_[1]
# Out:
# 70 80 82 72 58 58 60 63 54 58 60 48 89 115 121 119 115 110 98 91 84 84 90 99 110 126 143 153 158 171 169 172 169 165 129 110 113 107 95 79 66 62 56 57 61 52 43 41 65 61 58 57 56 69 75 70 65 56 54 105 146 154 151 151 155 155 150 147 147 148 152 158 164 172 177 182 186 189 188 190 188 180 167 116 95 103 97 77 72 62 55 58 54 56 52 44 50 43 54 64 63 71 68 64 52 66 119 156 161 164 163 164 167 168 170 174 175 176 178 179 183 187 190 195 197 198 197 198 195 191 190 145 86 100 90 65 57 60 54 51 41 49 56 47 38 44 63 55 46 52 54 55 83 138 157 158 165 168 172 171 173 176 179 179 180 182 185 187 189 189 192 197 200 199 196 198 200 198 197 177 91 87 96 58 58 59 51 42 37 41 47 45 37 35 36 30 41 47 59 94 141 159 161 161 164 170 171 172 176 178 179 182 183 183 187 189 192 192 194 195 200 200 199 199 200 201 197 193 111 71 108 69 55 61 51 42 43 56 54 44 24 29 31 45 61 72 100 136 150 159 163 162 163 170 172 171 174 177 177 180 187 186 187 189 192 192 194 195 196 197 199 200 201 200 197 201 137 58 98 9
# ...

# %%
pixes=lin1_[1].split(' ')
print len(pixes)
# Out:
# 2304

# %%
import numpy as np
img=np.reshape(pixes,(48,48))

# %%
from PIL import Image
my_img=Image.fromarray(img,'L')
my_img.save('/home/zzq/Downloads/fer2013/1.jpg')

# %%
print pixes[2:9]
# Out:
# ['82', '72', '58', '58', '60', '63', '54']

# %%
print img
# Out:
# [['70' '80' '82' ..., '52' '43' '41']
#  ['65' '61' '58' ..., '56' '52' '44']
#  ['50' '43' '54' ..., '49' '56' '47']
#  ...,
#  ['91' '65' '42' ..., '72' '56' '43']
#  ['77' '82' '79' ..., '105' '70' '46']
#  ['77' '72' '84' ..., '106' '109' '82']]

# %%
print lin1_[2]
# Out:
# Training

# %%
import numpy as np
g_loss=np.zeros(3000,dtype=float)

# %%
print g_loss.shape
# Out:
# (3000,)

# %%
input_images=[None]*3000
print len(input_images)
# Out:
# 3000
